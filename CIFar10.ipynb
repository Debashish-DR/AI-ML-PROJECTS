# %%
import keras
import cv2
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.optimizers import Adam
from keras.utils import to_categorical
import random
np.random.seed(0)
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
(x_train , y_train),(x_test , y_test) = cifar10.load_data()

print(x_train.shape)
print(x_test.shape)
print(y_train.shape[0])
# Out:
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)
# 50000

# %%
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
x_train=x_train.reshape(50000,32,32,3)
x_test=x_test.reshape(10000,32,32,3)

# %%
x_train = x_train/255
x_test = x_test/255

# %%
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    brightness_range=[0.8, 1.2],
    zoom_range=0.2
)
datagen.fit(x_train)

def Lenet_model():
  model = Sequential()
  model.add(Conv2D(30 , (5,5) , input_shape = (32,32,3) , activation = 'relu'))
  model.add(MaxPooling2D(pool_size = (2,2)))
  model.add(Conv2D(30 , (5,5) , activation = 'relu'))
  model.add(MaxPooling2D(pool_size = (2,2)))

  model.add(Flatten())
  model.add(Dense(200 , activation = 'relu'))
  model.add(Dense(100 , activation = 'relu'))

  model.add(Dense(10 , activation = 'softmax'))
  model.compile(Adam(learning_rate = 0.1) , loss = 'categorical_crossentropy' , metrics = (['accuracy']))
  return model

# %%
model = Lenet_model()

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 28, 28, 30)        2280
#
#  max_pooling2d_6 (MaxPoolin  (None, 14, 14, 30)        0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 10, 10, 30)        22530
#
#  max_pooling2d_7 (MaxPoolin  (None, 5, 5, 30)          0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 750)               0
#
#  dense_9 (Dense)             (None, 200)               150200
#
#  dense_10 (Dense)            (None, 100)               20100
#
#  dense_11 (Dense)            (None, 10)                1010
#
# =================================================================
# Total params: 196120 (766.09 KB)
# Trainable params: 196120 (766.09 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(x_train , y_train , validation_split = 0.1 , epochs = 10 , batch_size = 400, verbose = 1 , shuffle = 1)
# Out:
# Epoch 1/10
# 113/113 [==============================] - 58s 503ms/step - loss: 135.9252 - accuracy: 0.0961 - val_loss: 2.3103 - val_accuracy: 0.0986
# Epoch 2/10
# 113/113 [==============================] - 61s 540ms/step - loss: 2.3047 - accuracy: 0.1002 - val_loss: 2.3055 - val_accuracy: 0.0976
# Epoch 3/10
# 113/113 [==============================] - 58s 510ms/step - loss: 2.3052 - accuracy: 0.0972 - val_loss: 2.3058 - val_accuracy: 0.0976
# Epoch 4/10
# 113/113 [==============================] - 62s 550ms/step - loss: 2.3047 - accuracy: 0.1001 - val_loss: 2.3042 - val_accuracy: 0.0970
# Epoch 5/10
# 113/113 [==============================] - 58s 515ms/step - loss: 2.3046 - accuracy: 0.0996 - val_loss: 2.3038 - val_accuracy: 0.0970
# Epoch 6/10
# 113/113 [==============================] - 65s 576ms/step - loss: 2.3048 - accuracy: 0.0988 - val_loss: 2.3037 - val_accuracy: 0.1058
# Epoch 7/10
# 113/113 [==============================] - 56s 496ms/step - loss: 2.3052 - accuracy: 0.0983 - val_loss: 2.3048 - val_accuracy: 0.0976
# Epoch 8/10
# 113/113 [==============================] - 57s 506ms/step - loss: 2.3047 - accuracy: 0.0981 - val_loss: 2.3054 - val_accuracy: 0.0950
# Epoch 9/10
# 113/113 [==============================] - 60s 534ms/step - loss: 2.3054 - accuracy: 0.0998 - val_loss: 2.3033 - val_accuracy: 0.1038
# Epoch 10/10
# 113/113 [==============================] - 57s 503ms/step - loss: 2.3051 - accuracy: 0.1014 - val_loss: 2.3033 - val_accuracy: 0.1064
